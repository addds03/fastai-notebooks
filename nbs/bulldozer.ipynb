# %% [markdown]
# <a href="https://colab.research.google.com/github/addds03/fastai-notebooks/blob/main/nbs/bulldozer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from fastai.imports import *
from fastai.tabular import *

from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics 

from IPython.display import display

# %% [markdown]
# # Introduction to Bulldozer Data

# %%
df_raw = pd.read_csv('data/Train.csv', low_memory=False, parse_dates=['saledate'])

# %%
def display_all(df):
  with pd.option_context('display.max_rows', 1000):
    with pd.option_context('display.max_columns', 1000):
      display(df)

# %%
display_all(df_raw.tail().transpose())
# Out:
#                                                                      123368  \
# SalesID                                                             1467859
# SalePrice                                                             16000
# MachineID                                                           1225937
# ModelID                                                                4200
# datasource                                                              132
# auctioneerID                                                              2
# YearMade                                                               1989
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                2005-11-16 00:00:00
# fiModelDesc                                                           E120B
# ...

# %%
df_raw.SalePrice = np.log(df_raw.SalePrice)

# %% [markdown]
# Creating additional columns from saledate

# %%
add_datepart(df_raw, 'saledate')
df_raw.saleYear.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/tabular/transform.py:63: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   for n in attr: df[prefix + n] = getattr(field.dt, n.lower())
# 0    2006
# 1    2004
# 2    2004
# 3    2011
# 4    2009
# Name: saleYear, dtype: int64

# %% [markdown]
# ### Convert all the categories to numerical form

# %%
train_cats(df_raw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-9bfa7a41edd7> in <module>()
# ----> 1 train_cats(df_raw)
#
# NameError: name 'train_cats' is not defined
